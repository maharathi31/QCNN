# %%
import sys
print(sys.version)
# Out:
# 3.11.5 (main, Sep 11 2023, 08:31:25) [Clang 14.0.6 ]

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "./"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - 17ms/step - accuracy: 0.1800 - loss: 2.6726 - val_accuracy: 0.1667 - val_loss: 2.4006
# Epoch 2/30
# 13/13 - 0s - 2ms/step - accuracy: 0.2600 - loss: 1.8933 - val_accuracy: 0.2667 - val_loss: 2.2035
# Epoch 3/30
# 13/13 - 0s - 2ms/step - accuracy: 0.4800 - loss: 1.6098 - val_accuracy: 0.3000 - val_loss: 2.0170
# Epoch 4/30
# 13/13 - 0s - 2ms/step - accuracy: 0.6800 - loss: 1.2929 - val_accuracy: 0.5333 - val_loss: 1.8346
# Epoch 5/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8800 - loss: 1.0550 - val_accuracy: 0.5333 - val_loss: 1.7069
# Epoch 6/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9000 - loss: 0.8776 - val_accuracy: 0.5333 - val_loss: 1.6082
# Epoch 7/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9400 - loss: 0.7313 - val_accuracy: 0.5667 - val_loss: 1.5271
# Epoch 8/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.6176 - val_accuracy: 0.5667 - val_loss: 1.4608
# Epoch 9/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.5265 - val_accuracy: 0.5667 - val_loss: 1.4066
# Epoch 10/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.4534 - val_accuracy: 0.6333 - val_loss: 1.3622
# Epoch 11/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3943 - val_accuracy: 0.6333 - val_loss: 1.3250
# Epoch 12/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3457 - val_accuracy: 0.6333 - val_loss: 1.2936
# Epoch 13/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3054 - val_accuracy: 0.6333 - val_loss: 1.2670
# Epoch 14/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2717 - val_accuracy: 0.6333 - val_loss: 1.2442
# Epoch 15/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2434 - val_accuracy: 0.6333 - val_loss: 1.2246
# Epoch 16/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2193 - val_accuracy: 0.6667 - val_loss: 1.2075
# Epoch 17/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1986 - val_accuracy: 0.6667 - val_loss: 1.1926
# Epoch 18/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1809 - val_accuracy: 0.6667 - val_loss: 1.1793
# Epoch 19/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1655 - val_accuracy: 0.6667 - val_loss: 1.1676
# Epoch 20/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1520 - val_accuracy: 0.6667 - val_loss: 1.1570
# Epoch 21/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1403 - val_accuracy: 0.6667 - val_loss: 1.1476
# Epoch 22/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1299 - val_accuracy: 0.6667 - val_loss: 1.1390
# Epoch 23/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1206 - val_accuracy: 0.6667 - val_loss: 1.1312
# Epoch 24/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1124 - val_accuracy: 0.6667 - val_loss: 1.1241
# Epoch 25/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1051 - val_accuracy: 0.6667 - val_loss: 1.1175
# Epoch 26/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0985 - val_accuracy: 0.6667 - val_loss: 1.1116
# Epoch 27/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0925 - val_accuracy: 0.6667 - val_loss: 1.1060
# Epoch 28/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0871 - val_accuracy: 0.6667 - val_loss: 1.1009
# Epoch 29/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0822 - val_accuracy: 0.6667 - val_loss: 1.0962
# Epoch 30/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0777 - val_accuracy: 0.6667 - val_loss: 1.0918

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - 16ms/step - accuracy: 0.1400 - loss: 2.2979 - val_accuracy: 0.3667 - val_loss: 2.1101
# Epoch 2/30
# 13/13 - 0s - 2ms/step - accuracy: 0.5600 - loss: 1.8932 - val_accuracy: 0.3667 - val_loss: 1.9701
# Epoch 3/30
# 13/13 - 0s - 2ms/step - accuracy: 0.7600 - loss: 1.6130 - val_accuracy: 0.3667 - val_loss: 1.8452
# Epoch 4/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8200 - loss: 1.3838 - val_accuracy: 0.4333 - val_loss: 1.7302
# Epoch 5/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8400 - loss: 1.1924 - val_accuracy: 0.4667 - val_loss: 1.6289
# Epoch 6/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8800 - loss: 1.0333 - val_accuracy: 0.5000 - val_loss: 1.5435
# Epoch 7/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9200 - loss: 0.9014 - val_accuracy: 0.5000 - val_loss: 1.4725
# Epoch 8/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9200 - loss: 0.7916 - val_accuracy: 0.5000 - val_loss: 1.4135
# Epoch 9/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9400 - loss: 0.6998 - val_accuracy: 0.5667 - val_loss: 1.3638
# Epoch 10/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9600 - loss: 0.6224 - val_accuracy: 0.6000 - val_loss: 1.3216
# Epoch 11/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.5566 - val_accuracy: 0.6333 - val_loss: 1.2853
# Epoch 12/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.5003 - val_accuracy: 0.6333 - val_loss: 1.2540
# Epoch 13/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.4518 - val_accuracy: 0.6333 - val_loss: 1.2267
# Epoch 14/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.4098 - val_accuracy: 0.6333 - val_loss: 1.2028
# Epoch 15/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3732 - val_accuracy: 0.6333 - val_loss: 1.1818
# Epoch 16/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3411 - val_accuracy: 0.6667 - val_loss: 1.1631
# Epoch 17/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3129 - val_accuracy: 0.6667 - val_loss: 1.1466
# Epoch 18/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2880 - val_accuracy: 0.6667 - val_loss: 1.1318
# Epoch 19/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2658 - val_accuracy: 0.6667 - val_loss: 1.1185
# Epoch 20/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2461 - val_accuracy: 0.6667 - val_loss: 1.1066
# Epoch 21/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2285 - val_accuracy: 0.6667 - val_loss: 1.0958
# Epoch 22/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2127 - val_accuracy: 0.6667 - val_loss: 1.0860
# Epoch 23/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1984 - val_accuracy: 0.6667 - val_loss: 1.0771
# Epoch 24/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1856 - val_accuracy: 0.6667 - val_loss: 1.0690
# Epoch 25/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1740 - val_accuracy: 0.6667 - val_loss: 1.0617
# Epoch 26/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1634 - val_accuracy: 0.6667 - val_loss: 1.0549
# Epoch 27/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1538 - val_accuracy: 0.6667 - val_loss: 1.0487
# Epoch 28/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1451 - val_accuracy: 0.6667 - val_loss: 1.0430
# Epoch 29/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1371 - val_accuracy: 0.6667 - val_loss: 1.0377
# Epoch 30/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1297 - val_accuracy: 0.6667 - val_loss: 1.0329

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_w/vw1x_chj4193wcq3qzph9sl40000gn/T/ipykernel_32362/925943430.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
